# %%
#Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#Stats
from scipy import stats

# %%
#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotplib inline
# Out:
# UsageError: Line magic function `%matplotplib` not found.

# %%
dataset1 = randn(100)
dataset2 = randn(80)

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  5., 11., 20., 15., 12., 16.,  8.,  7.,  2.]),
#  array([-2.46580963, -1.97406496, -1.48232029, -0.99057562, -0.49883094,
#         -0.00708627,  0.4846584 ,  0.97640307,  1.46814774,  1.95989241,
#          2.45163708]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,density=True,color='red',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.08517474, 0.12776212, 0.04258737, 0.17034949, 0.17034949,
#         0.17034949, 0.51104846, 0.51104846, 0.38328635, 0.38328635,
#         0.34069898, 0.25552423, 0.12776212, 0.        , 0.04258737,
#         0.04258737, 0.        , 0.        , 0.        , 0.04258737]),
#  array([-2.24187851, -1.94836427, -1.65485003, -1.3613358 , -1.06782156,
#         -0.77430732, -0.48079308, -0.18727885,  0.10623539,  0.39974963,
#          0.69326387,  0.98677811,  1.28029234,  1.57380658,  1.86732082,
#          2.16083506,  2.45434929,  2.74786353,  3.04137777,  3.33489201,
#          3.62840625]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\avina\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x=data1,y=data2,kind='hex')
